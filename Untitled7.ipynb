# %% [markdown]
# <a href="https://colab.research.google.com/github/let53/Win7b/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Установка KDE Plasma и VNC через Bore

# %%
# 1. Установка KDE Plasma и VNC
# !apt-get update
# !export DEBIAN_FRONTEND=noninteractive && apt-get install -y kde-plasma-desktop tightvncserver

# %%
# 2. Настройка пароля и создание конфига для KDE
VNC_PASSWORD = "zte1g8" #@param {type:"string"}

# %env USER=root
# !mkdir -p ~/.vnc
# !echo {VNC_PASSWORD} | vncpasswd -f > ~/.vnc/passwd
# !chmod 600 ~/.vnc/passwd

# Создаем xstartup для запуска KDE
xstartup_content = """#!/bin/sh
unset SESSION_MANAGER
unset DBUS_SESSION_BUS_ADDRESS
startkde &
"""
with open(os.path.expanduser("~/.vnc/xstartup"), "w") as f:
    f.write(xstartup_content)
# !chmod +x ~/.vnc/xstartup

# Запуск VNC
# !vncserver -kill :1 2>/dev/null
# !vncserver :1 -geometry 1280x720 -depth 24
# Out:
# env: USER=root
#
# New 'X' desktop is 600821a4a5b7:1
#
# Starting applications specified in /root/.vnc/xstartup
# Log file is /root/.vnc/600821a4a5b7:1.log

# %%
# 3. Запуск туннеля Bore
import time
import os

# Проверяем наличие bore, если нет - качаем
if not os.path.exists('bore'):
    # !wget -q https://github.com/ekzhang/bore/releases/download/v0.5.1/bore-v0.5.1-x86_64-unknown-linux-musl.tar.gz
    # !tar -xf bore-v0.5.1-x86_64-unknown-linux-musl.tar.gz
    # !chmod +x bore

print("Запуск туннеля bore...")
get_ipython().system_raw('./bore local 5901 --to bore.pub > bore.log 2>&1 &')

time.sleep(5)

with open('bore.log', 'r') as f:
    print(f.read())
# Out:
# Запуск туннеля bore...
# 2026-03-27T07:46:31.756388Z  INFO bore_cli::client: connected to server remote_port=60794
# 2026-03-27T07:46:31.756454Z  INFO bore_cli::client: listening at bore.pub:60794
